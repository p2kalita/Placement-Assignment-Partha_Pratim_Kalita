# %% [markdown]
# ### Question 1 : Implement 3 different CNN architectures with a comparison table for the MNSIT dataset using the Tensorflow library

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Reshape and normalize input data
x_train = x_train.reshape(-1, 28, 28, 1) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1) / 255.0

# One-hot encode 
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# first CNN architecture
model1 = Sequential([
    Conv2D(4, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(10, activation='softmax')
])
print(model1.summary())
print('!!Starting Model 1 training!!')
# Compile and train the first model
model1.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model1.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
print('Model 1 trained successfully!')
print(100*"-")

# Desecond CNN architecture
model2 = Sequential([
    Conv2D(8, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(12, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(20, activation='relu'),
    Dense(10, activation='softmax')
])
model2.summary()
print('!!Starting Model 2 training!!')
# Compile and train the second model
model2.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model2.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
print('Model 2 trained successfully!')

print(100*"-")


print('!!Starting Model 3 training!!')
# Define the third CNN architecture
model3 = Sequential([
    Conv2D(8, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(16, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])
model3.summary()
# Compile and train the third model
model3.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model3.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
print('Model 3 trained successfully!')
print(100*"-")


# Evaluate the models on the test set
_, acc1 = model1.evaluate(x_test, y_test, verbose=0)
_, acc2 = model2.evaluate(x_test, y_test, verbose=0)
_, acc3 = model3.evaluate(x_test, y_test, verbose=0)

# Create a comparison table
print("CNN Architecture\t\tAccuracy")
print("-------------------------------------------------")
print("Model 1\t\t\t{:.2f}%".format(acc1 * 100))
print("Model 2\t\t\t{:.2f}%".format(acc2 * 100))
print("Model 3\t\t\t{:.2f}%".format(acc3 * 100))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 4)         40
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 4)        0
#  )
#
#  flatten (Flatten)           (None, 676)               0
#
#  dense (Dense)               (None, 10)                6770
#
# =================================================================
# Total params: 6,810
# Trainable params: 6,810
# Non-trainable params: 0
# _________________________________________________________________
# None
# !!Starting Model 1 training!!
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3972 - accuracy: 0.8872 - val_loss: 0.2402 - val_accuracy: 0.9314
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2205 - accuracy: 0.9356 - val_loss: 0.1934 - val_accuracy: 0.9420
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1785 - accuracy: 0.9477 - val_loss: 0.1590 - val_accuracy: 0.9545
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1494 - accuracy: 0.9571 - val_loss: 0.1394 - val_accuracy: 0.9592
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1284 - accuracy: 0.9627 - val_loss: 0.1231 - val_accuracy: 0.9638
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1140 - accuracy: 0.9667 - val_loss: 0.1126 - val_accuracy: 0.9663
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1026 - accuracy: 0.9699 - val_loss: 0.1106 - val_accuracy: 0.9666
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0934 - accuracy: 0.9725 - val_loss: 0.1024 - val_accuracy: 0.9691
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0880 - accuracy: 0.9739 - val_loss: 0.0939 - val_accuracy: 0.9703
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0819 - accuracy: 0.9754 - val_loss: 0.0919 - val_accuracy: 0.9715
# Model 1 trained successfully!
# ----------------------------------------------------------------------------------------------------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 8)         80
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 8)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 11, 11, 12)        876
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 12)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 300)               0
#
#  dense_1 (Dense)             (None, 20)                6020
#
#  dense_2 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 7,186
# Trainable params: 7,186
# Non-trainable params: 0
# _________________________________________________________________
# !!Starting Model 2 training!!
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2962 - accuracy: 0.9108 - val_loss: 0.1072 - val_accuracy: 0.9668
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1069 - accuracy: 0.9666 - val_loss: 0.0809 - val_accuracy: 0.9738
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0827 - accuracy: 0.9742 - val_loss: 0.0847 - val_accuracy: 0.9730
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0703 - accuracy: 0.9782 - val_loss: 0.0548 - val_accuracy: 0.9833
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0613 - accuracy: 0.9811 - val_loss: 0.0482 - val_accuracy: 0.9850
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0548 - accuracy: 0.9827 - val_loss: 0.0513 - val_accuracy: 0.9838
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0501 - accuracy: 0.9844 - val_loss: 0.0485 - val_accuracy: 0.9851
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0457 - accuracy: 0.9857 - val_loss: 0.0544 - val_accuracy: 0.9830
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0416 - accuracy: 0.9867 - val_loss: 0.0476 - val_accuracy: 0.9852
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0399 - accuracy: 0.9877 - val_loss: 0.0544 - val_accuracy: 0.9840
# Model 2 trained successfully!
# ----------------------------------------------------------------------------------------------------
# !!Starting Model 3 training!!
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 8)         80
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 8)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 16)        1168
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 16)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 32)          4640
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dense_4 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 7,274
# Trainable params: 7,274
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3497 - accuracy: 0.8909 - val_loss: 0.1617 - val_accuracy: 0.9461
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1477 - accuracy: 0.9539 - val_loss: 0.1050 - val_accuracy: 0.9678
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1113 - accuracy: 0.9650 - val_loss: 0.0943 - val_accuracy: 0.9702
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0928 - accuracy: 0.9710 - val_loss: 0.0884 - val_accuracy: 0.9733
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0831 - accuracy: 0.9743 - val_loss: 0.0940 - val_accuracy: 0.9721
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0742 - accuracy: 0.9770 - val_loss: 0.0817 - val_accuracy: 0.9740
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0669 - accuracy: 0.9793 - val_loss: 0.0844 - val_accuracy: 0.9737
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0626 - accuracy: 0.9805 - val_loss: 0.0688 - val_accuracy: 0.9793
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0585 - accuracy: 0.9812 - val_loss: 0.0720 - val_accuracy: 0.9777
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0532 - accuracy: 0.9834 - val_loss: 0.0766 - val_accuracy: 0.9775
# Model 3 trained successfully!
# ----------------------------------------------------------------------------------------------------
# CNN Architecture		Accuracy
# -------------------------------------------------
# Model 1			97.15%
# Model 2			98.40%
# Model 3			97.75%
