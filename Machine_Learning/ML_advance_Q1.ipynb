# %%
import dask.dataframe as dd
from dask_ml.model_selection import train_test_split
from dask_ml.linear_model import LogisticRegression
import mlflow
import mlflow.sklearn
import networkx as nx

# %%
mlflow.start_run()
df = dd.read_csv("train.csv")

# %%
df.head()
# Out:
#    source_node  destination_node
# 0            1            690569
# 1            1            315892
# 2            1            189226
# 3            2            834328
# 4            2           1615927

# %%
# Convert the source and destination nodes to Dask arrays
source_nodes = df['source_node'].to_dask_array(lengths=True)
destination_nodes = df['destination_node'].to_dask_array(lengths=True)

# Create a directed graph using NetworkX
G = nx.DiGraph()
edges = [(source, destination) for source, destination in zip(source_nodes.compute(), destination_nodes.compute())]
G.add_edges_from(edges)

# %%
# Calculate Common Neighbors
def common_neighbors_score(G, u, v):
    common_neighbors = set(G.successors(u)).intersection(G.successors(v))
    return len(common_neighbors)

# %%
# Calculate Jaccard's Coefficient
def jaccard_coefficient_score(G, u, v):
    u_neighbors = set(G.successors(u))
    v_neighbors = set(G.successors(v))
    intersection = u_neighbors.intersection(v_neighbors)
    union = u_neighbors.union(v_neighbors)
    return len(intersection) / len(union)

# %%
# Calculate Preferential Attachment
def preferential_attachment_score(G, u, v):
    u_neighbors = set(G.successors(u))
    v_neighbors = set(G.successors(v))
    return len(u_neighbors) * len(v_neighbors)

# %%
# Calculate scores for all pairs of nodes
for u, v in G.edges():
    common_neighbors = common_neighbors_score(G, u, v)
    jaccard_coefficient = jaccard_coefficient_score(G, u, v)
    preferential_attachment = preferential_attachment_score(G, u, v)
    
    # Log scores and other relevant information using MLflow
    with mlflow.start_run(nested=True):
        mlflow.log_param("Source Node", u)
        mlflow.log_param("Destination Node", v)
        mlflow.log_metric("Common Neighbors Score", common_neighbors)
        mlflow.log_metric("Preferential Attachment Score", preferential_attachment)
    
    print(f"Nodes {u} and {v}:")
    print(f"Common Neighbors Score: {common_neighbors}")
    print(f"Jaccard's Coefficient Score: {jaccard_coefficient}")
    print(f"Preferential Attachment Score: {preferential_attachment}")
    print("-------------")

# End the MLflow run
mlflow.end_run()
# Out:
# Streaming output truncated to the last 5000 lines.
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1519887 and 23572:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 98
# -------------
# Nodes 1214432 and 553971:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 180
# -------------
# Nodes 1214432 and 201115:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 450
# -------------
# Nodes 1214432 and 38390:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 90
# -------------
# Nodes 1214432 and 1420628:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 135
# -------------
# Nodes 1214432 and 1149460:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.018518518518518517
# Preferential Attachment Score: 600
# -------------
# Nodes 1214432 and 1047741:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 240
# -------------
# Nodes 1214432 and 1379161:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 75
# -------------
# Nodes 1214432 and 336680:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05714285714285714
# Preferential Attachment Score: 330
# -------------
# Nodes 1214432 and 501419:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 105
# -------------
# Nodes 1214432 and 66374:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 90
# -------------
# Nodes 1214432 and 1525016:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 210
# -------------
# Nodes 1214432 and 23572:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 105
# -------------
# Nodes 1214432 and 1317997:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 1214432 and 669757:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05
# Preferential Attachment Score: 90
# -------------
# Nodes 1214432 and 1271457:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 105
# -------------
# Nodes 1712244 and 23572:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 7
# -------------
# Nodes 1586998 and 1211177:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 126
# -------------
# Nodes 1586998 and 1175597:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 90
# -------------
# Nodes 1586998 and 1280197:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.045454545454545456
# Preferential Attachment Score: 126
# -------------
# Nodes 1586998 and 1464484:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1586998 and 23572:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 63
# -------------
# Nodes 1586998 and 1288215:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 36
# -------------
# Nodes 1586998 and 1221989:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 45
# -------------
# Nodes 1586998 and 472237:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 9
# -------------
# Nodes 1586998 and 315322:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 9
# -------------
# Nodes 23573 and 704872:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1
# -------------
# Nodes 704872 and 683408:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 11
# -------------
# Nodes 23574 and 668958:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05555555555555555
# Preferential Attachment Score: 88
# -------------
# Nodes 23574 and 467280:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 187
# -------------
# Nodes 23574 and 1305872:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 11
# -------------
# Nodes 23574 and 544543:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 187
# -------------
# Nodes 23574 and 1312441:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 198
# -------------
# Nodes 23574 and 1814401:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 77
# -------------
# Nodes 23574 and 85514:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 286
# -------------
# Nodes 23574 and 150853:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 66
# -------------
# Nodes 23574 and 793518:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.16666666666666666
# Preferential Attachment Score: 33
# -------------
# Nodes 23574 and 197575:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 33
# -------------
# Nodes 23574 and 1040679:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 22
# -------------
# Nodes 467280 and 936113:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.12121212121212122
# Preferential Attachment Score: 340
# -------------
# Nodes 467280 and 23574:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 187
# -------------
# Nodes 467280 and 1309387:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 884
# -------------
# Nodes 467280 and 989621:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 306
# -------------
# Nodes 467280 and 271685:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.12
# Preferential Attachment Score: 187
# -------------
# Nodes 467280 and 679004:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.17391304347826086
# Preferential Attachment Score: 170
# -------------
# Nodes 467280 and 888300:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.08
# Preferential Attachment Score: 170
# -------------
# Nodes 467280 and 1012062:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.09523809523809523
# Preferential Attachment Score: 102
# -------------
# Nodes 467280 and 1463223:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06451612903225806
# Preferential Attachment Score: 272
# -------------
# Nodes 467280 and 1211726:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 102
# -------------
# Nodes 467280 and 1312441:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.25
# Preferential Attachment Score: 306
# -------------
# Nodes 467280 and 1666183:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 85
# -------------
# Nodes 467280 and 286449:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.13043478260869565
# Preferential Attachment Score: 153
# -------------
# Nodes 467280 and 778419:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 170
# -------------
# Nodes 467280 and 1405635:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 119
# -------------
# Nodes 467280 and 315891:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05555555555555555
# Preferential Attachment Score: 34
# -------------
# Nodes 467280 and 1125412:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 17
# -------------
# Nodes 1305872 and 225311:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 13
# -------------
# Nodes 544543 and 1424955:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 204
# -------------
# Nodes 544543 and 518398:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 595
# -------------
# Nodes 544543 and 23574:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 187
# -------------
# Nodes 544543 and 191574:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.09259259259259259
# Preferential Attachment Score: 714
# -------------
# Nodes 544543 and 1265374:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 425
# -------------
# Nodes 544543 and 1092500:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.15
# Preferential Attachment Score: 493
# -------------
# Nodes 544543 and 981107:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 663
# -------------
# Nodes 544543 and 791157:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.07142857142857142
# Preferential Attachment Score: 731
# -------------
# Nodes 544543 and 830243:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.13333333333333333
# Preferential Attachment Score: 289
# -------------
# Nodes 544543 and 745594:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.16
# Preferential Attachment Score: 204
# -------------
# Nodes 544543 and 61231:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03125
# Preferential Attachment Score: 272
# -------------
# Nodes 544543 and 497979:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 255
# -------------
# Nodes 544543 and 114762:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.13793103448275862
# Preferential Attachment Score: 272
# -------------
# Nodes 544543 and 1622849:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.030303030303030304
# Preferential Attachment Score: 289
# -------------
# Nodes 544543 and 118195:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05405405405405406
# Preferential Attachment Score: 374
# -------------
# Nodes 544543 and 1814401:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 119
# -------------
# Nodes 544543 and 1171868:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 51
# -------------
# Nodes 1312441 and 960557:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 432
# -------------
# Nodes 1312441 and 23574:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 198
# -------------
# Nodes 1312441 and 467280:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.25
# Preferential Attachment Score: 306
# -------------
# Nodes 1312441 and 554224:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 90
# -------------
# Nodes 1312441 and 1012062:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.2
# Preferential Attachment Score: 108
# -------------
# Nodes 1312441 and 769238:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 270
# -------------
# Nodes 1312441 and 1463223:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.0967741935483871
# Preferential Attachment Score: 288
# -------------
# Nodes 1312441 and 1211726:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 108
# -------------
# Nodes 1312441 and 455638:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 36
# -------------
# Nodes 1312441 and 1666183:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 90
# -------------
# Nodes 1312441 and 1433419:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 126
# -------------
# Nodes 1312441 and 1362186:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 198
# -------------
# Nodes 1312441 and 793518:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 54
# -------------
# Nodes 1312441 and 810210:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 36
# -------------
# Nodes 1312441 and 603313:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1312441 and 553536:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 72
# -------------
# Nodes 1312441 and 1405635:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.08695652173913043
# Preferential Attachment Score: 126
# -------------
# Nodes 1312441 and 315891:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 36
# -------------
# Nodes 1814401 and 1531659:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 49
# -------------
# Nodes 1814401 and 82162:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 105
# -------------
# Nodes 1814401 and 23574:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 77
# -------------
# Nodes 1814401 and 488745:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03225806451612903
# Preferential Attachment Score: 175
# -------------
# Nodes 1814401 and 1213627:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 91
# -------------
# Nodes 1814401 and 544543:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 119
# -------------
# Nodes 1814401 and 849468:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 14
# -------------
# Nodes 85514 and 791636:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03333333333333333
# Preferential Attachment Score: 130
# -------------
# Nodes 85514 and 90191:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05714285714285714
# Preferential Attachment Score: 286
# -------------
# Nodes 85514 and 23574:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 286
# -------------
# Nodes 85514 and 420241:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 208
# -------------
# Nodes 85514 and 43718:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 780
# -------------
# Nodes 85514 and 1648889:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05128205128205128
# Preferential Attachment Score: 390
# -------------
# Nodes 85514 and 230189:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.025
# Preferential Attachment Score: 390
# -------------
# Nodes 85514 and 1464790:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.056338028169014086
# Preferential Attachment Score: 1274
# -------------
# Nodes 85514 and 956619:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 78
# -------------
# Nodes 85514 and 801367:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 208
# -------------
# Nodes 85514 and 1725736:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 260
# -------------
# Nodes 85514 and 293164:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.0967741935483871
# Preferential Attachment Score: 208
# -------------
# Nodes 85514 and 995988:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 182
# -------------
# Nodes 85514 and 1736932:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.020833333333333332
# Preferential Attachment Score: 598
# -------------
# Nodes 85514 and 474033:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1066
# -------------
# Nodes 85514 and 185774:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 85514 and 1483544:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 78
# -------------
# Nodes 85514 and 965214:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05714285714285714
# Preferential Attachment Score: 286
# -------------
# Nodes 85514 and 554957:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.07894736842105263
# Preferential Attachment Score: 390
# -------------
# Nodes 85514 and 1735497:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.0967741935483871
# Preferential Attachment Score: 208
# -------------
# Nodes 85514 and 1343340:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 85514 and 434741:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.14285714285714285
# Preferential Attachment Score: 156
# -------------
# Nodes 85514 and 562816:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06666666666666667
# Preferential Attachment Score: 156
# -------------
# Nodes 85514 and 996480:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 104
# -------------
# Nodes 85514 and 805343:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 85514 and 321140:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.034482758620689655
# Preferential Attachment Score: 104
# -------------
# Nodes 150853 and 16998:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 162
# -------------
# Nodes 150853 and 23574:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 66
# -------------
# Nodes 150853 and 612407:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 150853 and 793518:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 18
# -------------
# Nodes 150853 and 1803610:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.14285714285714285
# Preferential Attachment Score: 12
# -------------
# Nodes 150853 and 273856:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.14285714285714285
# Preferential Attachment Score: 12
# -------------
# Nodes 793518 and 1312441:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 54
# -------------
# Nodes 793518 and 150853:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 18
# -------------
# Nodes 793518 and 762438:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 24
# -------------
# Nodes 197575 and 101164:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 197575 and 23574:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 33
# -------------
# Nodes 197575 and 668958:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 1040679 and 23574:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 22
# -------------
# Nodes 1040679 and 39632:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 10
# -------------
# Nodes 23575 and 323097:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 8
# -------------
# Nodes 323097 and 1116240:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 208
# -------------
# Nodes 323097 and 554056:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 24
# -------------
# Nodes 323097 and 540209:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 323097 and 1821507:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 32
# -------------
# Nodes 323097 and 825707:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 104
# -------------
# Nodes 323097 and 684656:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 323097 and 1549263:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 323097 and 23575:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 8
# -------------
# Nodes 23576 and 1577245:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 160
# -------------
# Nodes 23576 and 1241698:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 96
# -------------
# Nodes 23576 and 117831:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.10714285714285714
# Preferential Attachment Score: 184
# -------------
# Nodes 23576 and 709559:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.10526315789473684
# Preferential Attachment Score: 104
# -------------
# Nodes 23576 and 660668:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 144
# -------------
# Nodes 23576 and 1206929:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 32
# -------------
# Nodes 23576 and 1755644:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.25
# Preferential Attachment Score: 56
# -------------
# Nodes 23576 and 1390119:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 8
# -------------
# Nodes 1577245 and 1094763:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 500
# -------------
# Nodes 1577245 and 812640:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1577245 and 1227456:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 360
# -------------
# Nodes 1577245 and 1054890:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 800
# -------------
# Nodes 1577245 and 1600509:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 760
# -------------
# Nodes 1577245 and 1500378:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 700
# -------------
# Nodes 1577245 and 885935:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 440
# -------------
# Nodes 1577245 and 299040:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 740
# -------------
# Nodes 1577245 and 1067508:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 260
# -------------
# Nodes 1577245 and 1766534:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 140
# -------------
# Nodes 1577245 and 23576:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 160
# -------------
# Nodes 1577245 and 1019693:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 180
# -------------
# Nodes 1577245 and 429746:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 240
# -------------
# Nodes 1577245 and 48859:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 80
# -------------
# Nodes 1577245 and 1252525:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 520
# -------------
# Nodes 1577245 and 1132420:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 20
# -------------
# Nodes 1577245 and 457961:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 20
# -------------
# Nodes 1577245 and 683978:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 40
# -------------
# Nodes 1577245 and 951822:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 220
# -------------
# Nodes 1577245 and 224540:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 1241698 and 1637465:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 480
# -------------
# Nodes 1241698 and 365916:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 168
# -------------
# Nodes 1241698 and 44999:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 456
# -------------
# Nodes 1241698 and 979365:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 108
# -------------
# Nodes 1241698 and 410894:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 192
# -------------
# Nodes 1241698 and 23576:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 96
# -------------
# Nodes 1241698 and 117831:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 276
# -------------
# Nodes 1241698 and 1369987:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 156
# -------------
# Nodes 1241698 and 175396:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.06666666666666667
# Preferential Attachment Score: 48
# -------------
# Nodes 1241698 and 1844820:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 36
# -------------
# Nodes 1241698 and 753397:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1241698 and 1036149:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 117831 and 878004:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.11904761904761904
# Preferential Attachment Score: 552
# -------------
# Nodes 117831 and 258435:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 184
# -------------
# Nodes 117831 and 1241698:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 276
# -------------
# Nodes 117831 and 806166:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.029411764705882353
# Preferential Attachment Score: 276
# -------------
# Nodes 117831 and 125728:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.13333333333333333
# Preferential Attachment Score: 253
# -------------
# Nodes 117831 and 986087:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 299
# -------------
# Nodes 117831 and 1105593:
# Common Neighbors Score: 9
# Jaccard's Coefficient Score: 0.21428571428571427
# Preferential Attachment Score: 644
# -------------
# Nodes 117831 and 456415:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.16
# Preferential Attachment Score: 138
# -------------
# Nodes 117831 and 1105617:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 621
# -------------
# Nodes 117831 and 604807:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.08
# Preferential Attachment Score: 92
# -------------
# Nodes 117831 and 617006:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.20512820512820512
# Preferential Attachment Score: 552
# -------------
# Nodes 117831 and 1169567:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.021739130434782608
# Preferential Attachment Score: 552
# -------------
# Nodes 117831 and 1342007:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 230
# -------------
# Nodes 117831 and 1552985:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.023809523809523808
# Preferential Attachment Score: 460
# -------------
# Nodes 117831 and 580652:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.022727272727272728
# Preferential Attachment Score: 506
# -------------
# Nodes 117831 and 1489763:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 253
# -------------
# Nodes 117831 and 1524734:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 138
# -------------
# Nodes 117831 and 1768042:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.12195121951219512
# Preferential Attachment Score: 529
# -------------
# Nodes 117831 and 1206929:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 92
# -------------
# Nodes 117831 and 1101791:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.029411764705882353
# Preferential Attachment Score: 276
# -------------
# Nodes 117831 and 183267:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 117831 and 1755644:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 161
# -------------
# Nodes 117831 and 349928:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 69
# -------------
# Nodes 709559 and 23576:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.10526315789473684
# Preferential Attachment Score: 104
# -------------
# Nodes 709559 and 1062905:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 260
# -------------
# Nodes 709559 and 1824305:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 234
# -------------
# Nodes 709559 and 953910:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 117
# -------------
# Nodes 709559 and 660668:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03333333333333333
# Preferential Attachment Score: 234
# -------------
# Nodes 709559 and 142486:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 195
# -------------
# Nodes 709559 and 1755644:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 91
# -------------
# Nodes 709559 and 1693003:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.09523809523809523
# Preferential Attachment Score: 130
# -------------
# Nodes 709559 and 39010:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 13
# -------------
# Nodes 709559 and 1786176:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.041666666666666664
# Preferential Attachment Score: 156
# -------------
# Nodes 709559 and 1440158:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 13
# -------------
# Nodes 709559 and 685018:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 26
# -------------
# Nodes 709559 and 1551388:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 91
# -------------
# Nodes 660668 and 1738479:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06666666666666667
# Preferential Attachment Score: 252
# -------------
# Nodes 660668 and 872041:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.030303030303030304
# Preferential Attachment Score: 288
# -------------
# Nodes 660668 and 709559:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03333333333333333
# Preferential Attachment Score: 234
# -------------
# Nodes 660668 and 940027:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 90
# -------------
# Nodes 660668 and 810453:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05
# Preferential Attachment Score: 54
# -------------
# Nodes 660668 and 1077117:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 144
# -------------
# Nodes 660668 and 1782576:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03571428571428571
# Preferential Attachment Score: 198
# -------------
# Nodes 660668 and 122955:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06060606060606061
# Preferential Attachment Score: 306
# -------------
# Nodes 660668 and 1101791:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07142857142857142
# Preferential Attachment Score: 216
# -------------
# Nodes 660668 and 1578284:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 144
# -------------
# Nodes 660668 and 407564:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.06818181818181818
# Preferential Attachment Score: 522
# -------------
# Nodes 660668 and 1462830:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03125
# Preferential Attachment Score: 270
# -------------
# Nodes 660668 and 1023912:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 36
# -------------
# Nodes 660668 and 492773:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 270
# -------------
# Nodes 660668 and 1693003:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 180
# -------------
# Nodes 660668 and 155526:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 660668 and 1160236:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 108
# -------------
# Nodes 660668 and 1707528:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05
# Preferential Attachment Score: 54
# -------------
# Nodes 1206929 and 320786:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 28
# -------------
# Nodes 1206929 and 591039:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 84
# -------------
# Nodes 1206929 and 1029592:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.06666666666666667
# Preferential Attachment Score: 48
# -------------
# Nodes 1206929 and 1273745:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 8
# -------------
# Nodes 1755644 and 23576:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.25
# Preferential Attachment Score: 56
# -------------
# Nodes 1755644 and 117831:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 161
# -------------
# Nodes 1755644 and 709559:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 91
# -------------
# Nodes 1755644 and 660668:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.041666666666666664
# Preferential Attachment Score: 126
# -------------
# Nodes 1755644 and 1588174:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03333333333333333
# Preferential Attachment Score: 168
# -------------
# Nodes 1755644 and 1804626:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 91
# -------------
# Nodes 1755644 and 1735701:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.14285714285714285
# Preferential Attachment Score: 7
# -------------
# Nodes 1390119 and 117831:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 23
# -------------
# Nodes 23577 and 1443014:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.5
# Preferential Attachment Score: 2
# -------------
# Nodes 23577 and 1569718:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.3333333333333333
# Preferential Attachment Score: 4
# -------------
# Nodes 1443014 and 1569718:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 2
# -------------
# Nodes 1569718 and 1443014:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 2
# -------------
# Nodes 1569718 and 23577:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.3333333333333333
# Preferential Attachment Score: 4
# -------------
# Nodes 23578 and 58599:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 4
# -------------
# Nodes 58599 and 912048:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 228
# -------------
# Nodes 58599 and 886177:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 68
# -------------
# Nodes 58599 and 1466172:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 58599 and 23578:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 4
# -------------
# Nodes 23579 and 410747:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 80
# -------------
# Nodes 23579 and 963834:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 140
# -------------
# Nodes 23579 and 1319565:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 190
# -------------
# Nodes 23579 and 1441365:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 160
# -------------
# Nodes 23579 and 731201:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 23579 and 1619038:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 120
# -------------
# Nodes 23579 and 1352794:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 20
# -------------
# Nodes 23579 and 842863:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 120
# -------------
# Nodes 23579 and 1377992:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.07142857142857142
# Preferential Attachment Score: 50
# -------------
# Nodes 23579 and 324042:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 20
# -------------
# Nodes 410747 and 229413:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 168
# -------------
# Nodes 410747 and 1372473:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 128
# -------------
# Nodes 410747 and 547488:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 128
# -------------
# Nodes 410747 and 1319565:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.08
# Preferential Attachment Score: 152
# -------------
# Nodes 410747 and 1270735:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 96
# -------------
# Nodes 410747 and 1636823:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 410747 and 1311387:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.08333333333333333
# Preferential Attachment Score: 40
# -------------
# Nodes 410747 and 23579:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 80
# -------------
# Nodes 963834 and 959518:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 963834 and 311571:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 196
# -------------
# Nodes 963834 and 303135:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.034482758620689655
# Preferential Attachment Score: 224
# -------------
# Nodes 963834 and 97086:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.13636363636363635
# Preferential Attachment Score: 154
# -------------
# Nodes 963834 and 1794200:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.13636363636363635
# Preferential Attachment Score: 154
# -------------
# Nodes 963834 and 1574552:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.17647058823529413
# Preferential Attachment Score: 84
# -------------
# Nodes 963834 and 1094861:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.19047619047619047
# Preferential Attachment Score: 154
# -------------
# Nodes 963834 and 1317327:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 98
# -------------
# Nodes 963834 and 1619038:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 168
# -------------
# Nodes 963834 and 653964:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 140
# -------------
# Nodes 963834 and 1805625:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 168
# -------------
# Nodes 963834 and 23579:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 140
# -------------
# Nodes 963834 and 422748:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 42
# -------------
# Nodes 963834 and 1575567:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05555555555555555
# Preferential Attachment Score: 70
# -------------
# Nodes 1319565 and 410747:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.08
# Preferential Attachment Score: 152
# -------------
# Nodes 1319565 and 868947:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.018867924528301886
# Preferential Attachment Score: 665
# -------------
# Nodes 1319565 and 53146:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.08
# Preferential Attachment Score: 152
# -------------
# Nodes 1319565 and 1330236:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 190
# -------------
# Nodes 1319565 and 98551:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.11764705882352941
# Preferential Attachment Score: 361
# -------------
# Nodes 1319565 and 1270735:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.2916666666666667
# Preferential Attachment Score: 228
# -------------
# Nodes 1319565 and 1116685:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1319565 and 1255900:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 171
# -------------
# Nodes 1319565 and 259804:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.034482758620689655
# Preferential Attachment Score: 209
# -------------
# Nodes 1319565 and 1234824:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05
# Preferential Attachment Score: 38
# -------------
# Nodes 1319565 and 23579:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 190
# -------------
# Nodes 1319565 and 238595:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.14285714285714285
# Preferential Attachment Score: 247
# -------------
# Nodes 1319565 and 842863:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.2916666666666667
# Preferential Attachment Score: 228
# -------------
# Nodes 1319565 and 1861725:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1319565 and 1824078:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 247
# -------------
# Nodes 1319565 and 539019:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03225806451612903
# Preferential Attachment Score: 247
# -------------
# Nodes 1319565 and 1304090:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 57
# -------------
# Nodes 1319565 and 1271498:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 19
# -------------
# Nodes 1319565 and 150116:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 731201 and 931728:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.06666666666666667
# Preferential Attachment Score: 60
# -------------
# Nodes 731201 and 1512567:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 36
# -------------
# Nodes 731201 and 291261:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 72
# -------------
# Nodes 731201 and 1497868:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 78
# -------------
# Nodes 731201 and 1251509:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 6
# -------------
# Nodes 731201 and 23579:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 1619038 and 963834:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 168
# -------------
# Nodes 1619038 and 221465:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.05555555555555555
# Preferential Attachment Score: 84
# -------------
# Nodes 1619038 and 628865:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 132
# -------------
# Nodes 1619038 and 770553:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07692307692307693
# Preferential Attachment Score: 192
# -------------
# Nodes 1619038 and 1641857:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.043478260869565216
# Preferential Attachment Score: 144
# -------------
# Nodes 1619038 and 1856503:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 192
# -------------
# Nodes 1619038 and 1355377:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 96
# -------------
# Nodes 1619038 and 1485112:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 120
# -------------
# Nodes 1619038 and 1565519:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.0625
# Preferential Attachment Score: 60
# -------------
# Nodes 1619038 and 23579:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.047619047619047616
# Preferential Attachment Score: 120
# -------------
# Nodes 1619038 and 1247441:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.07142857142857142
# Preferential Attachment Score: 36
# -------------
# Nodes 1619038 and 47862:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 12
# -------------
# Nodes 1352794 and 927269:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 1352794 and 23579:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 20
# -------------
# Nodes 842863 and 926689:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.10526315789473684
# Preferential Attachment Score: 108
# -------------
# Nodes 842863 and 53146:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 96
# -------------
# Nodes 842863 and 1319565:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.2916666666666667
# Preferential Attachment Score: 228
# -------------
# Nodes 842863 and 98551:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06896551724137931
# Preferential Attachment Score: 228
# -------------
# Nodes 842863 and 1270735:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.2631578947368421
# Preferential Attachment Score: 144
# -------------
# Nodes 842863 and 1116685:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 842863 and 259804:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.09523809523809523
# ...
# Preferential Attachment Score: 532
# -------------
# Nodes 1747976 and 283701:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 336
# -------------
# Nodes 1747976 and 620555:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 644
# -------------
# Nodes 1747976 and 737649:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 112
# -------------
# Nodes 1747976 and 23583:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 672
# -------------
# Nodes 1747976 and 1684018:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 364
# -------------
# Nodes 1747976 and 1310255:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 168
# -------------
# Nodes 1747976 and 354770:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02702702702702703
# Preferential Attachment Score: 280
# -------------
# Nodes 1747976 and 1534789:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 112
# -------------
# Nodes 1747976 and 1512449:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 140
# -------------
# Nodes 1747976 and 241428:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 28
# -------------
# Nodes 1747976 and 409236:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 56
# -------------
# Nodes 1747976 and 815237:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 308
# -------------
# Nodes 1747976 and 1665025:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 28
# -------------
# Nodes 1747976 and 198605:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1747976 and 288963:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 112
# -------------
# Nodes 1558262 and 1262443:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 1
# -------------
# Nodes 690020 and 1765544:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 108
# -------------
# Nodes 690020 and 214984:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 120
# -------------
# Nodes 690020 and 1094705:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 468
# -------------
# Nodes 690020 and 777354:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 132
# -------------
# Nodes 690020 and 227093:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 690020 and 1008181:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 120
# -------------
# Nodes 690020 and 1385177:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.0967741935483871
# Preferential Attachment Score: 264
# -------------
# Nodes 690020 and 1752262:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.09523809523809523
# Preferential Attachment Score: 132
# -------------
# Nodes 690020 and 1030134:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 690020 and 1715409:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05263157894736842
# Preferential Attachment Score: 336
# -------------
# Nodes 690020 and 1313716:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 60
# -------------
# Nodes 690020 and 962094:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 24
# -------------
# Nodes 615223 and 846615:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.08888888888888889
# Preferential Attachment Score: 598
# -------------
# Nodes 615223 and 88510:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02857142857142857
# Preferential Attachment Score: 299
# -------------
# Nodes 615223 and 1833669:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.034482758620689655
# Preferential Attachment Score: 161
# -------------
# Nodes 615223 and 1377503:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 161
# -------------
# Nodes 615223 and 1762033:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02127659574468085
# Preferential Attachment Score: 575
# -------------
# Nodes 615223 and 598265:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.030303030303030304
# Preferential Attachment Score: 253
# -------------
# Nodes 615223 and 218949:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 115
# -------------
# Nodes 615223 and 23583:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.021739130434782608
# Preferential Attachment Score: 552
# -------------
# Nodes 615223 and 1700349:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 437
# -------------
# Nodes 615223 and 1145919:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 230
# -------------
# Nodes 615223 and 264891:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05714285714285714
# Preferential Attachment Score: 322
# -------------
# Nodes 615223 and 1752262:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.030303030303030304
# Preferential Attachment Score: 253
# -------------
# Nodes 615223 and 1030134:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 115
# -------------
# Nodes 615223 and 1836771:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.029411764705882353
# Preferential Attachment Score: 276
# -------------
# Nodes 615223 and 477625:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03125
# Preferential Attachment Score: 230
# -------------
# Nodes 615223 and 388547:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 391
# -------------
# Nodes 615223 and 538188:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 299
# -------------
# Nodes 615223 and 969355:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.05405405405405406
# Preferential Attachment Score: 368
# -------------
# Nodes 615223 and 1211151:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.01818181818181818
# Preferential Attachment Score: 759
# -------------
# Nodes 615223 and 766144:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.1111111111111111
# Preferential Attachment Score: 161
# -------------
# Nodes 615223 and 1686671:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 23
# -------------
# Nodes 615223 and 1656318:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 138
# -------------
# Nodes 615223 and 1119737:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 23
# -------------
# Nodes 1289877 and 680148:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.017857142857142856
# Preferential Attachment Score: 782
# -------------
# Nodes 1289877 and 35821:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02127659574468085
# Preferential Attachment Score: 575
# -------------
# Nodes 1289877 and 1660634:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.02040816326530612
# Preferential Attachment Score: 621
# -------------
# Nodes 1289877 and 299672:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 506
# -------------
# Nodes 1289877 and 1632406:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.10714285714285714
# Preferential Attachment Score: 184
# -------------
# Nodes 1289877 and 1544159:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 483
# -------------
# Nodes 1289877 and 132553:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 345
# -------------
# Nodes 1289877 and 1476580:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.16
# Preferential Attachment Score: 138
# -------------
# Nodes 1289877 and 564445:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 161
# -------------
# Nodes 1289877 and 1551842:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 46
# -------------
# Nodes 1289877 and 1468682:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.19230769230769232
# Preferential Attachment Score: 184
# -------------
# Nodes 1289877 and 299129:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.025
# Preferential Attachment Score: 414
# -------------
# Nodes 1289877 and 23583:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 552
# -------------
# Nodes 1289877 and 1181996:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.12903225806451613
# Preferential Attachment Score: 276
# -------------
# Nodes 1289877 and 974696:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 46
# -------------
# Nodes 1289877 and 694117:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.041666666666666664
# Preferential Attachment Score: 46
# -------------
# Nodes 1289877 and 1595413:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 69
# -------------
# Nodes 1289877 and 260198:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.027777777777777776
# Preferential Attachment Score: 322
# -------------
# Nodes 1289877 and 865473:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 207
# -------------
# Nodes 1289877 and 1760301:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 46
# -------------
# Nodes 1289877 and 407257:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.037037037037037035
# Preferential Attachment Score: 115
# -------------
# Nodes 1289877 and 1758189:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 23
# -------------
# Nodes 1289877 and 734677:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.038461538461538464
# Preferential Attachment Score: 92
# -------------
# Nodes 1385177 and 1028574:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.038461538461538464
# Preferential Attachment Score: 110
# -------------
# Nodes 1385177 and 926341:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.07407407407407407
# Preferential Attachment Score: 154
# -------------
# Nodes 1385177 and 690020:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.0967741935483871
# Preferential Attachment Score: 264
# -------------
# Nodes 1385177 and 615223:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.07142857142857142
# Preferential Attachment Score: 506
# -------------
# Nodes 1385177 and 23583:
# Common Neighbors Score: 8
# Jaccard's Coefficient Score: 0.21052631578947367
# Preferential Attachment Score: 528
# -------------
# Nodes 1385177 and 537930:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 0
# -------------
# Nodes 1385177 and 1752262:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.17857142857142858
# Preferential Attachment Score: 242
# -------------
# Nodes 1385177 and 585143:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 308
# -------------
# Nodes 1385177 and 1715409:
# Common Neighbors Score: 7
# Jaccard's Coefficient Score: 0.16279069767441862
# Preferential Attachment Score: 616
# -------------
# Nodes 1385177 and 538188:
# Common Neighbors Score: 5
# Jaccard's Coefficient Score: 0.16666666666666666
# Preferential Attachment Score: 286
# -------------
# Nodes 1385177 and 881844:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.09090909090909091
# Preferential Attachment Score: 44
# -------------
# Nodes 1385177 and 1102424:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.2222222222222222
# Preferential Attachment Score: 242
# -------------
# Nodes 1385177 and 1313716:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 110
# -------------
# Nodes 1385177 and 277263:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 110
# -------------
# Nodes 1385177 and 1181343:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 22
# -------------
# Nodes 1385177 and 979178:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 22
# -------------
# Nodes 1385177 and 1466257:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 22
# -------------
# Nodes 1385177 and 1402930:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.045454545454545456
# Preferential Attachment Score: 22
# -------------
# Nodes 1385177 and 1803366:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.125
# Preferential Attachment Score: 110
# -------------
# Nodes 1385177 and 1525815:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.16666666666666666
# Preferential Attachment Score: 132
# -------------
# Nodes 1385177 and 662885:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 88
# -------------
# Nodes 1385177 and 1796416:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 22
# -------------
# Nodes 1697701 and 1424869:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06451612903225806
# Preferential Attachment Score: 182
# -------------
# Nodes 1697701 and 977627:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.03773584905660377
# Preferential Attachment Score: 754
# -------------
# Nodes 1697701 and 1496732:
# Common Neighbors Score: 6
# Jaccard's Coefficient Score: 0.08695652173913043
# Preferential Attachment Score: 1274
# -------------
# Nodes 1697701 and 572333:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.05970149253731343
# Preferential Attachment Score: 1170
# -------------
# Nodes 1697701 and 332060:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.0975609756097561
# Preferential Attachment Score: 494
# -------------
# Nodes 1697701 and 23583:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 624
# -------------
# Nodes 1697701 and 1087161:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 286
# -------------
# Nodes 1697701 and 1483526:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.04
# Preferential Attachment Score: 676
# -------------
# Nodes 1697701 and 1689340:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.08571428571428572
# Preferential Attachment Score: 312
# -------------
# Nodes 1697701 and 1179734:
# Common Neighbors Score: 4
# Jaccard's Coefficient Score: 0.13793103448275862
# Preferential Attachment Score: 182
# -------------
# Nodes 1697701 and 1047917:
# Common Neighbors Score: 3
# Jaccard's Coefficient Score: 0.1
# Preferential Attachment Score: 182
# -------------
# Nodes 1697701 and 870535:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.058823529411764705
# Preferential Attachment Score: 260
# -------------
# Nodes 1697701 and 518012:
# Common Neighbors Score: 1
# Jaccard's Coefficient Score: 0.03571428571428571
# Preferential Attachment Score: 78
# -------------
# Nodes 1697701 and 1629447:
# Common Neighbors Score: 0
# Jaccard's Coefficient Score: 0.0
# Preferential Attachment Score: 260
# -------------
# Nodes 1697701 and 1427800:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.06451612903225806
# Preferential Attachment Score: 182
# -------------
# Nodes 1697701 and 1102669:
# Common Neighbors Score: 2
# Jaccard's Coefficient Score: 0.045454545454545456
# Preferential Attachment Score: 520
# -------------
# Nodes 1697701 and 1690087:
# Common Neighbors Score: 1
